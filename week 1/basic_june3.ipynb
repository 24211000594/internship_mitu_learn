# %%
sent = "Hello, World!"

# %%
sent
# Out:
# 'Hello, World!'

# %%
sent = 'Hello, World!'

# %%
sent
# Out:
# 'Hello, World!'

# %%
#  docstring

# %%
sent = """
this is a multi -line-string.
it can span multiple lines.
it is often used for  docstring.

"""

# %%
print(sent)
# Out:
# this is a multi -line-string.
# it can span multiple lines.
# it is often used for  docstring.

# %%
sent = "hello python"

# %%
sent[0]
# Out:
# 'h'

# %%
sent[0:5]
# Out:
# 'hello'

# %%
# take aa string as user input
# print the output => index and character

# %%
c = 0
sent = input("enter the string:")
for i in sent:
    print(f"index: {c}, character: {i}")
    c += 1
# Out:
# enter the string: yash
# index: 0, character: y
# index: 1, character: a
# index: 2, character: s
# index: 3, character: h

# %%
sent = "ajit kumar; age:25; city: delhi; hobby: coding"

# %%
type(sent)
# Out:
# str

# %%
sent.split(";")
# Out:
# ['ajit kumar', ' age:25', ' city: delhi', ' hobby: coding']

# %%
sent.find("kumar")
# Out:
# 5

# %%
sent.find("k")
# Out:
# 5

# %%
s1 = "hello"

# %%
sent.index("kumar")
# Out:
# 5

# %%
sent.index("k")
# Out:
# 5

# %%
s1.index("llo")
# Out:
# 2

# %%
# split -> it  splits the string based on the  given delimeter  and  retutrns alist of substrings.

# join -> opposite of split

# %%
# user in -> string
# using loop split into individual character and store in list

# %%
sent = input("enter a string:")

l = []

for i in sent:
    l.append(i)

print(l)
# Out:
# enter a string: yash
# ['y', 'a', 's', 'h']

# %%
"""
take a string as user input
use a loop and if -  else to check if a specific chahracter is present in the string or not.
get output for both if the character is present and if it is not present.

take 2 characters to check in the string 

user input -> string, character1, character2
""";

# %%
text = input("enter a string:")
char1 = input("enter the first character to check:")
char2 = input("enter the second cahracter to check:")

found_char1 = False
found_char2 = False

for char in text:
    if char == char:
        found_char1 = True
    if char == char2:
        found_char = True

if found_char1:
    print(f"the character '{char1}' is present in string.")
else:
    print(f"the character '{char1}' is not present in the string.")
if found_char2:
    print(f"the character '{char1}' is present in string.")
else:
    print(f"the character '{char1}' is not present in the string.")
# Out:
# enter a string: yash
# enter the first character to check: y
# enter the second cahracter to check: a
# the character 'y' is present in string.
# the character 'y' is not present in the string.

# %%
# escape sequence

# %%
print("i like python programming\nits easy")
# Out:
# i like python programming
# its easy

# %%
print("i like python programming\t its easy")
# Out:
# i like python programming	 its easy

# %%
print("i like python programming\\t its easy")
# Out:
# i like python programming\t its easy

# %%
print("i like python programming\" its easy")
# Out:
# i like python programming" its easy

# %%
name = "ajit"
marks = 85

# %%
" my name is {} and my marks are {}".format(name, marks)
# Out:
# ' my name is ajit and my marks are 85'

# %%
# 1st question
text = input("Enter a string: ")

vowels = "aeiou"
count = 0
vowel_count = {}

for ch in text.lower():
    if ch in vowels:
        count += 1

        if ch in vowel_count:
            vowel_count[ch] += 1
        else:
            vowel_count[ch] = 1

print("Total vowels =", count)
print("Vowel counts =", vowel_count)
# Out:
# Enter a string:  yash
# Total vowels = 1
# Vowel counts = {'a': 1}

# %%
# 2nd quetion

text = input("Enter a string: ")
reversed_list = []

for i in range(len(text) - 1, -1, -1):
    reversed_list.append(text[i])


reversed_text = "".join(reversed_list)
if text == reversed_text:
    print("The string is a palindrome.")
else:
    print("The string is not a palindrome.")
# Out:
# Enter a string:  yash
# The string is not a palindrome.
