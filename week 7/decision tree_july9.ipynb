# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# banknotes.csv
df = pd.read_csv('banknotes.csv')
df
# Out:
#       Variance  Skewness  Curtosis  Entropy  Class
# 0      3.62160   8.66610   -2.8073 -0.44699      0
# 1      4.54590   8.16740   -2.4586 -1.46210      0
# 2      3.86600  -2.63830    1.9242  0.10645      0
# 3      3.45660   9.52280   -4.0112 -3.59440      0
# 4      0.32924  -4.45520    4.5718 -0.98880      0
# ...        ...       ...       ...      ...    ...
# 1367   0.40614   1.34920   -1.4501 -0.55949      1
# 1368  -1.38870  -4.87730    6.4774  0.34179      1
# 1369  -3.75030 -13.45860   17.5932 -2.77710      1
# 1370  -3.56370  -8.38270   12.3930 -1.28230      1
# 1371  -2.54190  -0.65804    2.6842  1.19520      1
#
# [1372 rows x 5 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1372 entries, 0 to 1371
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Variance  1372 non-null   float64
#  1   Skewness  1372 non-null   float64
#  2   Curtosis  1372 non-null   float64
#  3   Entropy   1372 non-null   float64
#  4   Class     1372 non-null   int64
# dtypes: float64(4), int64(1)
# memory usage: 53.7 KB

# %%
df.isnull().sum()
# Out:
# Variance    0
# Skewness    0
# Curtosis    0
# Entropy     0
# Class       0
# dtype: int64

# %%
#check for pattern through viz

# %%
import seaborn as sns

sns.pairplot(df, hue='Class')

# %%
x = df.drop('Class', axis = 1)
y = df['Class']

# %%
sns.countplot(x = y);

# %%
df['Class'].value_counts()
# Out:
# Class
# 0    762
# 1    610
# Name: count, dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.25,random_state=0)

# %%
x_train.shape, y_train.shape
# Out:
# ((1029, 4), (1029,))

# %%
from sklearn.tree import DecisionTreeClassifier
dt=  DecisionTreeClassifier()
dt.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
# evalute

# %%
y_pred = dt.predict(x_test)

# %%
from sklearn.metrics import accuracy_score
accuracy = accuracy_score(y_test, y_pred)

# %%
accuracy
# Out:
# 0.9795918367346939

# %%
x.columns
# Out:
# Index(['Variance', 'Skewness', 'Curtosis', 'Entropy'], dtype='object')

# %%
dt.feature_importances_
# Out:
# array([0.60347212, 0.23149511, 0.13861903, 0.02641374])

# %%
plt.title("Feature Importances")
plt.xlabel("Features")
plt.ylabel("Importance")
plt.bar(x.columns, dt.feature_importances_);

# %%
# plot the tree

# %%
from sklearn.tree import plot_tree

# %%
plt.figure(figsize=(16,22))
plot_tree(dt, rounded = True,fontsize=7,filled = True,feature_names= x.columns)
# Out:
# [Text(0.4991319444444444, 0.9444444444444444, 'Variance <= 0.274\ngini = 0.495\nsamples = 1029\nvalue = [567, 462]'),
#  Text(0.3298611111111111, 0.8333333333333334, 'Skewness <= 7.565\ngini = 0.298\nsamples = 495\nvalue = [90, 405]'),
#  Text(0.4144965277777778, 0.8888888888888888, 'True  '),
#  Text(0.22916666666666666, 0.7222222222222222, 'Variance <= -0.471\ngini = 0.129\nsamples = 417\nvalue = [29, 388]'),
#  Text(0.1111111111111111, 0.6111111111111112, 'Curtosis <= 6.746\ngini = 0.061\nsamples = 349\nvalue = [11, 338]'),
#  Text(0.05555555555555555, 0.5, 'Skewness <= 7.293\ngini = 0.008\nsamples = 249\nvalue = [1.0, 248.0]'),
#  Text(0.027777777777777776, 0.3888888888888889, 'gini = 0.0\nsamples = 245\nvalue = [0, 245]'),
#  Text(0.08333333333333333, 0.3888888888888889, 'Variance <= -2.509\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.05555555555555555, 0.2777777777777778, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.1111111111111111, 0.2777777777777778, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.16666666666666666, 0.5, 'Skewness <= -4.8\ngini = 0.18\nsamples = 100\nvalue = [10, 90]'),
#  Text(0.1388888888888889, 0.3888888888888889, 'gini = 0.0\nsamples = 90\nvalue = [0, 90]'),
#  Text(0.19444444444444445, 0.3888888888888889, 'gini = 0.0\nsamples = 10\nvalue = [10, 0]'),
#  Text(0.3472222222222222, 0.6111111111111112, 'Curtosis <= 0.297\ngini = 0.389\nsamples = 68\nvalue = [18, 50]'),
#  Text(0.2777777777777778, 0.5, 'Skewness <= 5.632\ngini = 0.085\nsamples = 45\nvalue = [2, 43]'),
#  Text(0.25, 0.3888888888888889, 'gini = 0.0\nsamples = 43\nvalue = [0, 43]'),
#  Text(0.3055555555555556, 0.3888888888888889, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.4166666666666667, 0.5, 'Entropy <= 0.728\ngini = 0.423\nsamples = 23\nvalue = [16, 7]'),
#  Text(0.3611111111111111, 0.3888888888888889, 'Variance <= 0.2\ngini = 0.124\nsamples = 15\nvalue = [14, 1]'),
#  Text(0.3333333333333333, 0.2777777777777778, 'gini = 0.0\nsamples = 14\nvalue = [14, 0]'),
#  Text(0.3888888888888889, 0.2777777777777778, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.4722222222222222, 0.3888888888888889, 'Curtosis <= 6.251\ngini = 0.375\nsamples = 8\nvalue = [2, 6]'),
#  Text(0.4444444444444444, 0.2777777777777778, 'gini = 0.0\nsamples = 6\nvalue = [0, 6]'),
#  Text(0.5, 0.2777777777777778, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.4305555555555556, 0.7222222222222222, 'Variance <= -4.726\ngini = 0.341\nsamples = 78\nvalue = [61, 17]'),
#  Text(0.4027777777777778, 0.6111111111111112, 'gini = 0.0\nsamples = 17\nvalue = [0, 17]'),
#  Text(0.4583333333333333, 0.6111111111111112, 'gini = 0.0\nsamples = 61\nvalue = [61, 0]'),
#  Text(0.6684027777777778, 0.8333333333333334, 'Curtosis <= -4.394\ngini = 0.191\nsamples = 534\nvalue = [477, 57]'),
#  Text(0.5837673611111112, 0.8888888888888888, '  False'),
#  Text(0.5486111111111112, 0.7222222222222222, 'Skewness <= 7.192\ngini = 0.375\nsamples = 32\nvalue = [8, 24]'),
#  Text(0.5208333333333334, 0.6111111111111112, 'gini = 0.0\nsamples = 24\nvalue = [0, 24]'),
#  Text(0.5763888888888888, 0.6111111111111112, 'gini = 0.0\nsamples = 8\nvalue = [8, 0]'),
#  Text(0.7881944444444444, 0.7222222222222222, 'Variance <= 1.565\ngini = 0.123\nsamples = 502\nvalue = [469, 33]'),
#  Text(0.6319444444444444, 0.6111111111111112, 'Curtosis <= -1.734\ngini = 0.348\nsamples = 134\nvalue = [104, 30]'),
#  Text(0.5555555555555556, 0.5, 'Skewness <= 5.289\ngini = 0.346\nsamples = 27\nvalue = [6, 21]'),
#  Text(0.5277777777777778, 0.3888888888888889, 'gini = 0.0\nsamples = 21\nvalue = [0, 21]'),
#  Text(0.5833333333333334, 0.3888888888888889, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(0.7083333333333334, 0.5, 'Entropy <= 0.834\ngini = 0.154\nsamples = 107\nvalue = [98, 9]'),
#  Text(0.6388888888888888, 0.3888888888888889, 'Entropy <= 0.106\ngini = 0.093\nsamples = 102\nvalue = [97, 5]'),
#  Text(0.5833333333333334, 0.2777777777777778, 'Curtosis <= -1.434\ngini = 0.023\nsamples = 86\nvalue = [85, 1]'),
#  Text(0.5555555555555556, 0.16666666666666666, 'Entropy <= -1.11\ngini = 0.278\nsamples = 6\nvalue = [5, 1]'),
#  Text(0.5277777777777778, 0.05555555555555555, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.5833333333333334, 0.05555555555555555, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.6111111111111112, 0.16666666666666666, 'gini = 0.0\nsamples = 80\nvalue = [80, 0]'),
#  Text(0.6944444444444444, 0.2777777777777778, 'Skewness <= 0.245\ngini = 0.375\nsamples = 16\nvalue = [12, 4]'),
#  Text(0.6666666666666666, 0.16666666666666666, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.7222222222222222, 0.16666666666666666, 'gini = 0.0\nsamples = 12\nvalue = [12, 0]'),
#  Text(0.7777777777777778, 0.3888888888888889, 'Variance <= 0.945\ngini = 0.32\nsamples = 5\nvalue = [1, 4]'),
#  Text(0.75, 0.2777777777777778, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.8055555555555556, 0.2777777777777778, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.9444444444444444, 0.6111111111111112, 'Variance <= 2.037\ngini = 0.016\nsamples = 368\nvalue = [365, 3]'),
#  Text(0.9166666666666666, 0.5, 'Curtosis <= -2.648\ngini = 0.117\nsamples = 48\nvalue = [45, 3]'),
#  Text(0.8888888888888888, 0.3888888888888889, 'Skewness <= 6.473\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.8611111111111112, 0.2777777777777778, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.9166666666666666, 0.2777777777777778, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.9444444444444444, 0.3888888888888889, 'gini = 0.0\nsamples = 44\nvalue = [44, 0]'),
#  Text(0.9722222222222222, 0.5, 'gini = 0.0\nsamples = 320\nvalue = [320, 0]')]

# %%
df = sns.load_dataset('tips')

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]
