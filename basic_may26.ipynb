# %%
# string functions

# %%
name = "yash"

# %%
name.lower()
# Out:
# 'yash'

# %%
name
# Out:
# 'yash'

# %%
name = name.lower()

# %%
name
# Out:
# 'yash'

# %%
name.upper()
# Out:
# 'YASH'

# %%
name.title()
# Out:
# 'Yash'

# %%
name = "Yash"

# %%
name.swapcase()
# Out:
# 'yASH'

# %%
name.isupper()
# Out:
# False

# %%
name.islower()
# Out:
# False

# %%
name.istitle()
# Out:
# True

# %%
name1 = "ok"
name2 = "123"
name3 = "ok123"

# %%
name1.isalpha()
# Out:
# True

# %%
name2.isalpha()
# Out:
# False

# %%
name3.isalpha()
# Out:
# False

# %%
name1.isdigit()
# Out:
# False

# %%
name2.isdigit()
# Out:
# True

# %%
name3.isdigit()
# Out:
# False

# %%
name3.isalnum()
# Out:
# True

# %%
name1.isalnum()
# Out:
# True

# %%
name = " pune "

# %%
print(name)
# Out:
#  pune

# %%
name.startswith("p")
# Out:
# False

# %%
name.startswith(" p")
# Out:
# True

# %%
name.endswith(" pune ")
# Out:
# True

# %%
name.endswith("e")
# Out:
# False

# %%
name.endswith("e ")
# Out:
# True

# %%
name.lstrip()
# Out:
# 'pune '

# %%
name.rstrip()
# Out:
# ' pune'

# %%
name.strip()
# Out:
# 'pune'

# %%
name
# Out:
# ' pune '

# %%
len(name)
# Out:
# 6

# %%
name.replace('u', 'oo')
# Out:
# ' poone '

# %% [markdown]
# Operators

# %%
# arithmetic

# %%
a + b
# Out:
# 22

# %%
a - b
# Out:
# -12

# %%
b / a
# Out:
# 3.4

# %%
a * b
# Out:
# 85

# %%
a ** b # raise to
# Out:
# 762939453125

# %%
b // a # floor div
# Out:
# 3

# %%
b % a
# Out:
# 2

# %%
# assignment operator

# %%
z = 5

# %%
z
# Out:
# 5

# %%
z = z + 3
z
# Out:
# 17

# %%
z += 3
z
# Out:
# 20

# %%
z -= 3
z
# Out:
# 14

# %%
z *= 3
z
# Out:
# 126

# %%
# camparison

# %%
a
# Out:
# 5

# %%
b
# Out:
# 17

# %%
a > b
# Out:
# False

# %%
a < b
# Out:
# True

# %%
a >= b
# Out:
# False

# %%
a <= b
# Out:
# True

# %%
a == b
# Out:
# False

# %%
a != b
# Out:
# True

# %%
# logical operator

# %%
a = True
b = False

# %%
a and b
# Out:
# False

# %%
a or b
# Out:
# True

# %%
not a
# Out:
# False

# %%
not b
# Out:
# True

# %%
# identity operator -> is, is not

# %%
a = 5
b = 5

# %%
id(a), id(b)
# Out:
# (140724429104168, 140724429104168)

# %%
a is b
# Out:
# True

# %%
a = [3, 4]
b = [3, 4]

# %%
id(a), id(b)
# Out:
# (1730699625024, 1730699638144)

# %%
a is b
# Out:
# False

# %%
a is not b
# Out:
# True

# %%
z = a

# %%
z is a
# Out:
# True

# %%
z
# Out:
# [3, 4]

# %%
a.append(10)
a
# Out:
# [3, 4, 10]

# %%
z
# Out:
# [3, 4, 10]

# %%
# membership selection operator -> in

# %%
l = [4, 6, 19, 10]

# %%
6 in l
# Out:
# True

# %%
2 in l
# Out:
# False

# %%
2 not in l
# Out:
# True

# %% [markdown]
# precedence and association

# %%
# bodmos

# %%
5 + 2 - 10
# Out:
# -3

# %%
(4 - 2) ** 2
# Out:
# 4

# %%
2 ** 2 ** 3 # right  association
# Out:
# 256

# %%
2 ** 3 // 2
# Out:
# 4

# %%
# print function

# %%
name = "yash"
marks = 76.52

# %%
# my name is yash and marks are 76.52

# %%
print("my name is", name, "and marks are",  marks)
# Out:
# my name is yash and marks are 76.52

# %%
print("my name is %s and marks are %i" %(name, marks))
# Out:
# my name is yash and marks are 76

# %%
print(f"my name is {name} and marks are {marks}")
# Out:
# my name is yash and marks are 76.52

# %%
# dir and help

# %%
dir(name);

# %%
help(name.strip)
# Out:
# Help on built-in function strip:
#
# strip(chars=None, /) method of builtins.str instance
#     Return a copy of the string with leading and trailing whitespace removed.
#
#     If chars is given and not None, remove characters in chars instead.

# %%
# ascii

# %%
ord("a")
# Out:
# 97

# %%
ord("A")
# Out:
# 65

# %%
chr(65)
# Out:
# 'A'

# %%
chr(35)
# Out:
# '#'

# %%
# type casting

# %%
num1 = 34
num2 = 44.56
num3 = "ok"

# %%
type(num1)
# Out:
# int

# %%
float(num1)
# Out:
# 34.0

# %%
int(num2)
# Out:
# 44

# %%
str(num2)
# Out:
# '44.56'

# %%
str(num1)
# Out:
# '34'

# %%
int(num3)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[145], line 1
# ----> 1 int(num3)
#
# ValueError: invalid literal for int() with base 10: 'ok'

# %%
# user input

# %%
a =input("enter the number")
# Out:
# enter the number 8

# %%
print('ok')
# Out:
# ok

# %%
a =int(input("enter the 1st number"))
b =int(input("enter the 2nd number"))

z = a + b

print("addition is =>",z)
# Out:
# enter the 1st number 9
# enter the 2nd number 66
# addition is => 75

# %%
a =int(input("enter the time"))
