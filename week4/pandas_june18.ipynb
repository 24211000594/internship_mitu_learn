# %%
# %pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

df = pd.read_csv("student1.csv")

# %%
df
# Out:
#     1     anil  TE  56.77  22
# 0   2     amit  TE  59.77  21
# 1   3   aniket  BE  76.88  19
# 2   4  ajinkya  TE  69.66  20
# 3   5     asha  TE  63.28  20
# 4   6   ayesha  BE  49.55  20
# 5   7     amar  BE  65.34  19
# 6   8    amita  BE  68.33  23
# 7   9     amol  TE  56.75  20
# 8  10    anmol  BE  78.66  21

# %%
col  = ['roll', 'name', 'class', 'marks', 'age']

# %%
df = pd.read_csv("student1.csv", names = col)
df
# Out:
#    roll     name class  marks  age
# 0     1     anil    TE  56.77   22
# 1     2     amit    TE  59.77   21
# 2     3   aniket    BE  76.88   19
# 3     4  ajinkya    TE  69.66   20
# 4     5     asha    TE  63.28   20
# 5     6   ayesha    BE  49.55   20
# 6     7     amar    BE  65.34   19
# 7     8    amita    BE  68.33   23
# 8     9     amol    TE  56.75   20
# 9    10    anmol    BE  78.66   21

# %%
df.iloc[1:4, 1:4]
# Out:
#       name class  marks
# 1     amit    TE  59.77
# 2   aniket    BE  76.88
# 3  ajinkya    TE  69.66

# %%
df.iloc[1:5, [0,1,3]]
# Out:
#    roll     name  marks
# 1     2     amit  59.77
# 2     3   aniket  76.88
# 3     4  ajinkya  69.66
# 4     5     asha  63.28

# %%
df.iloc[6:7,[0,1,3]]
# Out:
#    roll  name  marks
# 6     7  amar  65.34

# %%
df.iloc[[1,2,3,4,6],[0,1,3]]
# Out:
#    roll     name  marks
# 1     2     amit  59.77
# 2     3   aniket  76.88
# 3     4  ajinkya  69.66
# 4     5     asha  63.28
# 6     7     amar  65.34

# %%
df.iloc[5,1] = 'geet'

# %%
df
# Out:
#    roll     name class  marks  age
# 0     1     anil    TE  56.77   22
# 1     2     amit    TE  59.77   21
# 2     3   aniket    BE  76.88   19
# 3     4  ajinkya    TE  69.66   20
# 4     5     asha    TE  63.28   20
# 5     6     geet    BE  49.55   20
# 6     7     amar    BE  65.34   19
# 7     8    amita    BE  68.33   23
# 8     9     amol    TE  56.75   20
# 9    10    anmol    BE  78.66   21

# %%
# loc

# %%
df.loc[2:5, 'name']
# Out:
# 2     aniket
# 3    ajinkya
# 4       asha
# 5       geet
# Name: name, dtype: object

# %%
df.loc[2:5, ['name', 'class']]
# Out:
#       name class
# 2   aniket    BE
# 3  ajinkya    TE
# 4     asha    TE
# 5     geet    BE

# %%
df.loc[0:9, 'name']
# Out:
# 0       anil
# 1       amit
# 2     aniket
# 3    ajinkya
# 4       asha
# 5       geet
# 6       amar
# 7      amita
# 8       amol
# 9      anmol
# Name: name, dtype: object

# %%
df.loc[:, 'name']
# Out:
# 0       anil
# 1       amit
# 2     aniket
# 3    ajinkya
# 4       asha
# 5       geet
# 6       amar
# 7      amita
# 8       amol
# 9      anmol
# Name: name, dtype: object

# %%
df['name']
# Out:
# 0       anil
# 1       amit
# 2     aniket
# 3    ajinkya
# 4       asha
# 5       geet
# 6       amar
# 7      amita
# 8       amol
# 9      anmol
# Name: name, dtype: object

# %%
df[['name', 'class']]
# Out:
#       name class
# 0     anil    TE
# 1     amit    TE
# 2   aniket    BE
# 3  ajinkya    TE
# 4     asha    TE
# 5     geet    BE
# 6     amar    BE
# 7    amita    BE
# 8     amol    TE
# 9    anmol    BE

# %%
df['name'] .str.upper()
# Out:
# 0       ANIL
# 1       AMIT
# 2     ANIKET
# 3    AJINKYA
# 4       ASHA
# 5       GEET
# 6       AMAR
# 7      AMITA
# 8       AMOL
# 9      ANMOL
# Name: name, dtype: object

# %%
df['name'].str.lower()
# Out:
# 0       anil
# 1       amit
# 2     aniket
# 3    ajinkya
# 4       asha
# 5       geet
# 6       amar
# 7      amita
# 8       amol
# 9      anmol
# Name: name, dtype: object

# %%
df.replace('amit', 'yash')
# Out:
#    roll     name class  marks  age
# 0     1     anil    TE  56.77   22
# 1     2     yash    TE  59.77   21
# 2     3   aniket    BE  76.88   19
# 3     4  ajinkya    TE  69.66   20
# 4     5     asha    TE  63.28   20
# 5     6     geet    BE  49.55   20
# 6     7     amar    BE  65.34   19
# 7     8    amita    BE  68.33   23
# 8     9     amol    TE  56.75   20
# 9    10    anmol    BE  78.66   21

# %%
gender = ['m', 'm', 'm', 'm', 'f', 'f', 'm', 'm', 'm', 'm']

# %%
df['gender'] = gender

# %%
df
# Out:
#    roll     name class  marks  age gender
# 0     1     anil    TE  56.77   22      m
# 1     2     amit    TE  59.77   21      m
# 2     3   aniket    BE  76.88   19      m
# 3     4  ajinkya    TE  69.66   20      m
# 4     5     asha    TE  63.28   20      f
# 5     6     geet    BE  49.55   20      f
# 6     7     amar    BE  65.34   19      m
# 7     8    amita    BE  68.33   23      m
# 8     9     amol    TE  56.75   20      m
# 9    10    anmol    BE  78.66   21      m

# %%
df['roll'] = df['roll'] + 100

# %%
df
# Out:
#    roll     name class  marks  age gender
# 0   101     anil    TE  56.77   22      m
# 1   102     amit    TE  59.77   21      m
# 2   103   aniket    BE  76.88   19      m
# 3   104  ajinkya    TE  69.66   20      m
# 4   105     asha    TE  63.28   20      f
# 5   106     geet    BE  49.55   20      f
# 6   107     amar    BE  65.34   19      m
# 7   108    amita    BE  68.33   23      m
# 8   109     amol    TE  56.75   20      m
# 9   110    anmol    BE  78.66   21      m

# %%
df['cgpa'] = df['marks']/10 + 1.5

# %%
df
# Out:
#    roll     name class  marks  age gender   cgpa
# 0   101     anil    TE  56.77   22      m  7.177
# 1   102     amit    TE  59.77   21      m  7.477
# 2   103   aniket    BE  76.88   19      m  9.188
# 3   104  ajinkya    TE  69.66   20      m  8.466
# 4   105     asha    TE  63.28   20      f  7.828
# 5   106     geet    BE  49.55   20      f  6.455
# 6   107     amar    BE  65.34   19      m  8.034
# 7   108    amita    BE  68.33   23      m  8.333
# 8   109     amol    TE  56.75   20      m  7.175
# 9   110    anmol    BE  78.66   21      m  9.366

# %%
df.sort_values(by = 'name')
# Out:
#    roll     name class  marks  age gender   cgpa
# 3   104  ajinkya    TE  69.66   20      m  8.466
# 6   107     amar    BE  65.34   19      m  8.034
# 1   102     amit    TE  59.77   21      m  7.477
# 7   108    amita    BE  68.33   23      m  8.333
# 8   109     amol    TE  56.75   20      m  7.175
# 2   103   aniket    BE  76.88   19      m  9.188
# 0   101     anil    TE  56.77   22      m  7.177
# 9   110    anmol    BE  78.66   21      m  9.366
# 4   105     asha    TE  63.28   20      f  7.828
# 5   106     geet    BE  49.55   20      f  6.455

# %%
df.sort_values(['class', 'marks'])
# Out:
#    roll     name class  marks  age gender   cgpa
# 5   106     geet    BE  49.55   20      f  6.455
# 6   107     amar    BE  65.34   19      m  8.034
# 7   108    amita    BE  68.33   23      m  8.333
# 2   103   aniket    BE  76.88   19      m  9.188
# 9   110    anmol    BE  78.66   21      m  9.366
# 8   109     amol    TE  56.75   20      m  7.175
# 0   101     anil    TE  56.77   22      m  7.177
# 1   102     amit    TE  59.77   21      m  7.477
# 4   105     asha    TE  63.28   20      f  7.828
# 3   104  ajinkya    TE  69.66   20      m  8.466

# %%
df['marks'].mean()
# Out:
# np.float64(64.499)

# %%
df['marks'].max()
# Out:
# 78.66

# %%
df.describe()
# Out:
#             roll      marks        age       cgpa
# count   10.00000  10.000000  10.000000  10.000000
# mean   105.50000  64.499000  20.500000   7.949900
# std      3.02765   9.207179   1.269296   0.920718
# min    101.00000  49.550000  19.000000   6.455000
# 25%    103.25000  57.520000  20.000000   7.252000
# 50%    105.50000  64.310000  20.000000   7.931000
# 75%    107.75000  69.327500  21.000000   8.432750
# max    110.00000  78.660000  23.000000   9.366000

# %%
# group by

# %%
gr = df.groupby('class')

# %%
gr.groups
# Out:
# {'BE': [2, 5, 6, 7, 9], 'TE': [0, 1, 3, 4, 8]}

# %%
# filtering the data of those student -> marks > 60 and belong to be class

# %%
df.drop([4,5,6])
# Out:
#    roll     name class  marks  age gender   cgpa
# 0   101     anil    TE  56.77   22      m  7.177
# 1   102     amit    TE  59.77   21      m  7.477
# 2   103   aniket    BE  76.88   19      m  9.188
# 3   104  ajinkya    TE  69.66   20      m  8.466
# 7   108    amita    BE  68.33   23      m  8.333
# 8   109     amol    TE  56.75   20      m  7.175
# 9   110    anmol    BE  78.66   21      m  9.366

# %%
df.drop('name', axis = 1)
# Out:
#    roll class  marks  age gender   cgpa
# 0   101    TE  56.77   22      m  7.177
# 1   102    TE  59.77   21      m  7.477
# 2   103    BE  76.88   19      m  9.188
# 3   104    TE  69.66   20      m  8.466
# 4   105    TE  63.28   20      f  7.828
# 5   106    BE  49.55   20      f  6.455
# 6   107    BE  65.34   19      m  8.034
# 7   108    BE  68.33   23      m  8.333
# 8   109    TE  56.75   20      m  7.175
# 9   110    BE  78.66   21      m  9.366

# %%
df.drop(['name','class'], axis = 1)
# Out:
#    roll  marks  age gender   cgpa
# 0   101  56.77   22      m  7.177
# 1   102  59.77   21      m  7.477
# 2   103  76.88   19      m  9.188
# 3   104  69.66   20      m  8.466
# 4   105  63.28   20      f  7.828
# 5   106  49.55   20      f  6.455
# 6   107  65.34   19      m  8.034
# 7   108  68.33   23      m  8.333
# 8   109  56.75   20      m  7.175
# 9   110  78.66   21      m  9.366

# %%
df
# Out:
#    roll     name class  marks  age gender   cgpa
# 0   101     anil    TE  56.77   22      m  7.177
# 1   102     amit    TE  59.77   21      m  7.477
# 2   103   aniket    BE  76.88   19      m  9.188
# 3   104  ajinkya    TE  69.66   20      m  8.466
# 4   105     asha    TE  63.28   20      f  7.828
# 5   106     geet    BE  49.55   20      f  6.455
# 6   107     amar    BE  65.34   19      m  8.034
# 7   108    amita    BE  68.33   23      m  8.333
# 8   109     amol    TE  56.75   20      m  7.175
# 9   110    anmol    BE  78.66   21      m  9.366

# %%
df.drop(['gender', 'cgpa'], axis = 1, inplace = True )

# %%
df
# Out:
#    roll     name class  marks  age
# 0   101     anil    TE  56.77   22
# 1   102     amit    TE  59.77   21
# 2   103   aniket    BE  76.88   19
# 3   104  ajinkya    TE  69.66   20
# 4   105     asha    TE  63.28   20
# 5   106     geet    BE  49.55   20
# 6   107     amar    BE  65.34   19
# 7   108    amita    BE  68.33   23
# 8   109     amol    TE  56.75   20
# 9   110    anmol    BE  78.66   21

# %%
newdf = pd.DataFrame({
    'roll': df['roll'],
    'gender': gender,
    'cgpa': df['marks']/10 + 1.5
})

# %%
newdf
# Out:
#    roll gender   cgpa
# 0   101      m  7.177
# 1   102      m  7.477
# 2   103      m  9.188
# 3   104      m  8.466
# 4   105      f  7.828
# 5   106      f  6.455
# 6   107      m  8.034
# 7   108      m  8.333
# 8   109      m  7.175
# 9   110      m  9.366

# %%
pd.merge(df, newdf)
# Out:
#    roll     name class  marks  age gender   cgpa
# 0   101     anil    TE  56.77   22      m  7.177
# 1   102     amit    TE  59.77   21      m  7.477
# 2   103   aniket    BE  76.88   19      m  9.188
# 3   104  ajinkya    TE  69.66   20      m  8.466
# 4   105     asha    TE  63.28   20      f  7.828
# 5   106     geet    BE  49.55   20      f  6.455
# 6   107     amar    BE  65.34   19      m  8.034
# 7   108    amita    BE  68.33   23      m  8.333
# 8   109     amol    TE  56.75   20      m  7.175
# 9   110    anmol    BE  78.66   21      m  9.366

# %%
#  concate

# %%
df = pd.read_csv("student5.csv")

# %%
df
# Out:
#    roll     name class  marks  age
# 0     1   surbhi    TE  67.44   23
# 1     2    sujay    TE  74.12   22
# 2     3  subhash    BE  82.44   21
# 3     4   sachin    TE  59.33   21
# 4     5  shalini    TE  63.45   20

# %%
pd.concat([df, newdf], ignore_index = True)
# Out:
#     roll     name class  marks   age gender   cgpa
# 0      1   surbhi    TE  67.44  23.0    NaN    NaN
# 1      2    sujay    TE  74.12  22.0    NaN    NaN
# 2      3  subhash    BE  82.44  21.0    NaN    NaN
# 3      4   sachin    TE  59.33  21.0    NaN    NaN
# 4      5  shalini    TE  63.45  20.0    NaN    NaN
# 5    101      NaN   NaN    NaN   NaN      m  7.177
# 6    102      NaN   NaN    NaN   NaN      m  7.477
# 7    103      NaN   NaN    NaN   NaN      m  9.188
# 8    104      NaN   NaN    NaN   NaN      m  8.466
# 9    105      NaN   NaN    NaN   NaN      f  7.828
# 10   106      NaN   NaN    NaN   NaN      f  6.455
# 11   107      NaN   NaN    NaN   NaN      m  8.034
# 12   108      NaN   NaN    NaN   NaN      m  8.333
# 13   109      NaN   NaN    NaN   NaN      m  7.175
# 14   110      NaN   NaN    NaN   NaN      m  9.366
